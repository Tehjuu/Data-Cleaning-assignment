# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import dataset

# %%
book = pd.read_csv('./BL-Flickr-Images-Book.csv')

# %% [markdown]
# ### Checking the first 5 entries

# %%
book.head(5)
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %% [markdown]
# ### Dropping the specified column

# %%
book.drop(book.columns[[1,8,9,-5,-4,7,-3,-1]],axis=1,inplace=True)

# %% [markdown]
# ### Checking the first five entries again

# %%
book.head(5)
# Out:
#    Identifier      Place of Publication Date of Publication  \
# 0         206                    London         1879 [1878]
# 1         216  London; Virtue & Yorston                1868
# 2         218                    London                1869
# 3         472                    London                1851
# 4         480                    London                1857
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of “All for Gr...
# 3          James Darling  Welsh Sketches, chiefly ecclesiastical, to the...
# 4   Wertheim & Macintosh  [The World in which I live, and my place in it...
#
#       Author                                         Flickr URL
# 0      A. A.  http://www.flickr.com/photos/britishlibrary/ta...
# ...

# %%
book.set_index('Identifier',inplace=True)

# %% [markdown]
# ### Checking the first five entries again

# %%
book.head(5)
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London         1879 [1878]
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472         Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# ...

# %% [markdown]
# ### Using iloc function to access any data

# %%
book.iloc[:,[0,2]]
# Out:
#                 Place of Publication                Publisher
# Identifier
# 206                           London         S. Tinsley & Co.
# 216         London; Virtue & Yorston             Virtue & Co.
# 218                           London    Bradbury, Evans & Co.
# 472                           London            James Darling
# 480                           London     Wertheim & Macintosh
# ...                              ...                      ...
# 4158088                       London                      NaN
# 4158128                        Derby          M. Mozley & Son
# 4159563                       London  T. Cadell and W. Davies
# 4159587          Newcastle upon Tyne         Mackenzie & Dent
# 4160339                       London                      NaN
#
# [8287 rows x 2 columns]

# %%
book.iloc[1:2]
# Out:
#                 Place of Publication Date of Publication     Publisher  \
# Identifier
# 216         London; Virtue & Yorston                1868  Virtue & Co.
#
#                                                         Title     Author  \
# Identifier
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
#
#                                                    Flickr URL
# Identifier
# 216         http://www.flickr.com/photos/britishlibrary/ta...

# %% [markdown]
# ### Using loc function to access any data

# %%
book.loc[:,["Publisher","Title"]]
# Out:
#                           Publisher  \
# Identifier
# 206                S. Tinsley & Co.
# 216                    Virtue & Co.
# 218           Bradbury, Evans & Co.
# 472                   James Darling
# 480            Wertheim & Macintosh
# ...                             ...
# 4158088                         NaN
# 4158128             M. Mozley & Son
# 4159563     T. Cadell and W. Davies
# 4159587            Mackenzie & Dent
# 4160339                         NaN
#
#                                                         Title
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A
# 216         All for Greed. [A novel. The dedication signed...
# 218         Love the Avenger. By the author of “All for Gr...
# 472         Welsh Sketches, chiefly ecclesiastical, to the...
# 480         [The World in which I live, and my place in it...
# ...                                                       ...
# 4158088     The Parochial History of Cornwall, founded on,...
# ...

# %%
book.loc[[206,218,472,480],["Publisher","Title","Author"]]
# Out:
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
#
#                                                         Title     Author
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472         Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# 480         [The World in which I live, and my place in it...  A., E. S.

# %% [markdown]
# ### Finding the number of dtypes in the data

# %%
book.dtypes.value_counts()
# Out:
# object    6
# dtype: int64

# %%
book.describe()
# Out:
#        Place of Publication Date of Publication        Publisher  \
# count                  8287                8106             4092
# unique                 1441                1148             1989
# top                  London                1897  Macmillan & Co.
# freq                   3868                 157               85
#
#                                                     Title  \
# count                                                8287
# unique                                               8210
# top     [A General Gazetteer, in miniature ... The who...
# freq                                                    6
#
#                       Author  \
# count                   6509
# unique                  5005
# top     Shakespeare, William
# freq                      48
#
#                                                Flickr URL
# count                                                8287
# unique                                               8287
# ...

# %%
book.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8287 entries, 206 to 4160339
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Place of Publication  8287 non-null   object
#  1   Date of Publication   8106 non-null   object
#  2   Publisher             4092 non-null   object
#  3   Title                 8287 non-null   object
#  4   Author                6509 non-null   object
#  5   Flickr URL            8287 non-null   object
# dtypes: object(6)
# memory usage: 711.2+ KB
